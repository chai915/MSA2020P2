# %%
import json
import sys
sys.path.append('/home/nbuser/library/')

import pandas as pd
import requests

# %%
df = pd.read_csv('Properties.csv')

# %% [markdown]
# Get census population from website using API key

# %%
def get_censuspop(longitude, latitude): 
    
    url = 'https://koordinates.com/services/query/v1/vector.json'

    params = {
        'key' : 'ca0bc1cb19404c25a7d8aa7d17a63534',
        'layer' : '104612',
        'x' : longitude,
        'y' : latitude

    }

    response = requests.get(url, params=params)
    
    if response.status_code != 200:
        return response.status_code
    
    censuspop = response.json()['vectorQuery']['layers']['104612']['features'][0]['properties']['C18_CURPop']
    
    return censuspop

# %%
df['Census Results'] = df.apply(lambda row: get_censuspop(row['Longitude'], 
                                                        row['Latitude']), axis = 1)

# %%
df
# Out:
#       Bedrooms  Bathrooms                                          Address  \
# 0            5        3.0        106 Lawrence Crescent Hill Park, Auckland
# 1            5        3.0                   8 Corsica Way Karaka, Auckland
# 2            6        4.0           243 Harbourside Drive Karaka, Auckland
# 3            2        1.0        2/30 Hardington Street Onehunga, Auckland
# 4            3        1.0           59 Israel Avenue Clover Park, Auckland
# 5            3        1.0       14 Tainui Terrace Mangere Bridge, Auckland
# 6            3        1.0            54 Kelmarna Avenue Ponsonby, Auckland
# 7            3        2.0          39 Rawhiti Road One Tree Hill, Auckland
# 8            3        2.0             17b Tawa Crescent Manurewa, Auckland
# 9            4        2.0                39a Keegan Drive Massey, Auckland
# 10           4        2.0                39c Keegan Drive Massey, Auckland
# ...

# %% [markdown]
# Insert in the Deprivation Index from Otago data (merge on SA1)

# %%
df2 = pd.read_excel("otagodata.xlsx")

# %%
merged_df = pd.merge(left=df, right=df2[['SA12018_code', 'NZDep2018']], 
                  how='left', left_on='SA1', right_on='SA12018_code').drop('SA12018_code', axis = 1)

# %%
merged_df.head(10)
# Out:
#    Bedrooms  Bathrooms                                     Address Land area  \
# 0         5        3.0   106 Lawrence Crescent Hill Park, Auckland       714
# 1         5        3.0              8 Corsica Way Karaka, Auckland       564
# 2         6        4.0      243 Harbourside Drive Karaka, Auckland       626
# 3         2        1.0   2/30 Hardington Street Onehunga, Auckland        65
# 4         3        1.0      59 Israel Avenue Clover Park, Auckland       601
# 5         3        1.0  14 Tainui Terrace Mangere Bridge, Auckland       100
# 6         3        1.0       54 Kelmarna Avenue Ponsonby, Auckland       531
# 7         3        2.0     39 Rawhiti Road One Tree Hill, Auckland      1024
# 8         3        2.0        17b Tawa Crescent Manurewa, Auckland        80
# 9         4        2.0           39a Keegan Drive Massey, Auckland       204
#
#         CV   Latitude   Longitude      SA1  0-19 years  20-29 years  \
# ...

# %% [markdown]
# Convert final dataframe to csv

# %%
merged_df.to_csv("final_dataset.csv")
